# %% [markdown]
# # Tarea: Uso de Condicionales (if / else)

# %% [markdown]
# ## Parte 1: Condicionales en la vida diaria
# Escribe 3 oraciones de situaciones reales donde usarías un "si... entonces...".
#
# Ejemplo:
# Si me despierto tarde, entonces llego tarde a la escuela.
#
# 1.Si estudio con anticipación, entonces me siento más tranquilo durante el examen.
#
# 2.Si no cargo mi celular en la noche, entonces se queda sin batería durante el día.
#
# 3.Si llego temprano a la estación, entonces alcanzo el bus sin problema.

# %% [markdown]
# ## Parte 2: Explicación de la importancia de las condicionales
# Explica 4 ejemplos donde se vea por qué son necesarias las condicionales.
#
# Ejemplo modelo:
#
#
# *   Situación: Decidir si llevo paraguas.
# *   Condición: Si está lloviendo.
# *   Si se cumple: Llevo paraguas.
# *   Si no se cumple: Salgo sin paraguas.
#
#
#
# 1.
# *   Situación:Elegir qué ropa ponerme.
# *   Condición:Si hace frío.
# *   Si se cumple:Me pongo un abrigo y ropa más abrigada.
# *   Si no se cumple:Uso ropa ligera.
#
# 2.
# *   Situación:Planear si salir a caminar.
# *   Condición:Si tengo tiempo libre.
# *   Si se cumple:Salgo a caminar un rato.
# *   Si no se cumple:Me quedo en casa haciendo mis pendientes.
#
# 3.
# *   Situación:Decidir si preparo comida extra.
# *   Condición:Si vienen invitados.
# *   Si se cumple:Cocino más porciones.
# *   Si no se cumple:Preparo solo lo necesario para mí.
#
# 4.
# *   Situación:Elegir si tomar el transporte público o caminar.
# *   Condición:Si el destino está cerca
# *   Si se cumple:Camino para ahorrar tiempo y dinero.
# *   Si no se cumple:Tomo el transporte para llegar más rápido.

# %% [markdown]
# ## Parte 3: Condicionales en Python

# %% [markdown]
# ### Ejercicio 1
# Pide la hora (0-23). Si es menor que 12 muestra 'Es mañana', si no 'Es tarde o noche'.

# %%
hora = int(input("Ingresa la hora (0-23): "))

if hora < 12:
    print("Es mañana")
else:
    print("Es tarde o noche")
# Out:
# Ingresa la hora (0-23): 23
# Es tarde o noche

# %% [markdown]
# ### Ejercicio 2
# Pide dos números y muestra cuál es mayor o si son iguales.

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))

if numero1 > numero2:
    print("El primer número es mayor.")
elif num2 > num1:
    print("El segundo número es mayor.")
else:
    print("Ambos números son iguales.")
# Out:
# Ingresa el primer número: 4
# Ingresa el segundo número: 3
# El primer número es mayor.

# %% [markdown]
# ### Ejercicio 3
# Pide un número entero y muestra si es par o impar.

# %%
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    print("El número es par.")
else:
    print("El número es impar.")
# Out:
# Ingresa un número entero: 5
# El número es impar.
